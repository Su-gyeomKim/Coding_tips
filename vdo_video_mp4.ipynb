# %% [markdown]
# <a href="https://colab.research.google.com/github/Su-gyeomKim/Coding_tips/blob/master/vdo_video_mp4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Get mp4 file

# %%
# หาไฟล์ทั้งหมด ที่เป็น mp4
# !find / -name "*.mp4"
# Out:
# /usr/local/lib/python2.7/dist-packages/imageio/resources/images/realshort.mp4
# /usr/local/lib/python2.7/dist-packages/imageio/resources/images/cockatoo.mp4
# /usr/local/lib/python3.6/dist-packages/imageio/resources/images/realshort.mp4
# /usr/local/lib/python3.6/dist-packages/imageio/resources/images/cockatoo.mp4

# %%
# copy มา 1 ไฟล์ มาไว้ที่ directory ปัจจุบัน
# !cp /usr/local/lib/python3.6/dist-packages/imageio/resources/images/\
realshort.mp4 video.mp4
# !ls -al
# Out:
# total 112
# drwxr-xr-x 1 root root  4096 Apr  2 10:01 .
# drwxr-xr-x 1 root root  4096 Apr  2 09:57 ..
# drwxr-xr-x 1 root root  4096 Mar 31 16:39 .config
# drwxr-xr-x 1 root root  4096 Mar 18 16:23 sample_data
# -rw-r--r-- 1 root root 96822 Apr  2 10:35 video.mp4

# %% [markdown]
# ## Display

# %%
# แปลงไฟล์เป็น string ในรูปแบบ data url
from IPython.display import HTML
from base64 import b64encode
mp4 = open('video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
# แสดงผลด้วย vdo tag    ใครงง ก็ไปเรียน HTML ใน Sololearn ได้
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %% [markdown]
# # [bit.ly/mp4colab](https://bit.ly/mp4colab)
